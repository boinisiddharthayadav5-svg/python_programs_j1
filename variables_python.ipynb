# %% [markdown]
# # Variables in python
# 1. variables is memory allocation to value
# 2. examples are name="shivaji", salary=20000.65
#    ## key points to define variables
#    1. variables do not start with digit
#    2. variables does not allowed special charecters
#    3. do not keywords as a variables

# %%
name= "vikas"
age=20
salary=4500.65
print(age)
print(salary)
# Out:
# 20
# 4500.65

# %%
1name="shivaji"
print(1name)
# Out:
#   Cell In[2], line 1
#     1name="shivaji"
#     ^
# SyntaxError: invalid decimal literal

# %%
name@="vikas"
print(while)
# Out:
#   Cell In[3], line 2
#     print(while)
#           ^
# SyntaxError: invalid syntax
