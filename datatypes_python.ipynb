# %% [markdown]
# # data types of python
# 1.python have 3 data types
# 2.int(integer)
# 3.str(string)
# 4.float(decimals)

# %%
name="shivaji123"
age=25
salary=1000.25
print(age)
print(salary)
# Out:
# 25
# 1000.25

# %%
data="120"
print(data)
print(type(data))
# Out:
# 120
# <class 'str'>

# %%
a=100
b=120
print(a+b)
# Out:
# 220

# %%
v1=100
v2=100.25
print(v1+v2)
# Out:
# 200.25
